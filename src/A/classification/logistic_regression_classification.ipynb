# %% [markdown]
# # SCIKIT LEARN PART

# %%
# INICIALIZE THE MODEL OF LOGISTIC REGRESSION
# TO SEE MORE LINEAR MODELS: https://scikit-learn.org/stable/modules/linear_model.html#
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()
