# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

dataset = pd.read_csv('../../datasets/housing.csv')
dataset.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY

# %%
dataset.shape
# Out:
# (20433, 10)

# %%
dataset.isnull().sum()
# Out:
# longitude               0
# latitude                0
# housing_median_age      0
# total_rooms             0
# total_bedrooms        207
# population              0
# households              0
# median_income           0
# median_house_value      0
# ocean_proximity         0
# dtype: int64

# %%
dataset.dropna(inplace= True)
dataset.isnull().sum().sum()
# Out:
# np.int64(0)

# %%
dataset_view = dataset.drop(columns=['ocean_proximity'])
dataset_view.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value
# 0       322.0       126.0         8.3252            452600.0
# 1      2401.0      1138.0         8.3014            358500.0
# 2       496.0       177.0         7.2574            352100.0
# 3       558.0       219.0         5.6431            341300.0
# 4       565.0       259.0         3.8462            342200.0

# %%
dataset_view.columns
# Out:
# Index(['longitude', 'latitude', 'housing_median_age', 'total_rooms',
#        'total_bedrooms', 'population', 'households', 'median_income',
#        'median_house_value'],
#       dtype='object')

# %%
sns.scatterplot(x='latitude', y='median_house_value', data=dataset_view)
# Out:
# <Axes: xlabel='latitude', ylabel='median_house_value'>

# %%
dataset_view.skew().sort_values(ascending= False)
# Out:
# population            4.960017
# total_rooms           4.158816
# total_bedrooms        3.459546
# households            3.413850
# median_income         1.644557
# median_house_value    0.978290
# latitude              0.464934
# housing_median_age    0.061605
# longitude            -0.296141
# dtype: float64

# %%
corr = dataset_view.corr()
corr['median_house_value'].sort_values(ascending=False)
# Out:
# median_house_value    1.000000
# median_income         0.688355
# total_rooms           0.133294
# housing_median_age    0.106432
# households            0.064894
# total_bedrooms        0.049686
# population           -0.025300
# longitude            -0.045398
# latitude             -0.144638
# Name: median_house_value, dtype: float64

# %%
sns.heatmap(corr);

# %%
sns.histplot(dataset['median_house_value'])
# Out:
# <Axes: xlabel='median_house_value', ylabel='Count'>
