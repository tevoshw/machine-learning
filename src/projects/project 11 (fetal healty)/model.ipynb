# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, PolynomialFeatures
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LinearRegression, SGDRegressor
from sklearn.tree import DecisionTreeRegressor, plot_tree
from sklearn.metrics import mean_absolute_error, r2_score
import numpy as np



df = pd.read_csv("../../datasets/fetal_health.csv")

# %% [markdown]
# # Model With no select features (Linear Regression)

# %%
X = df.drop(columns=['fetal_health'])
y = df['fetal_health']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size= 0.25, random_state= 42)
model = Pipeline([
    ("Scaler", StandardScaler()),
    ('linear', LinearRegression())
])
model.fit(X_train, y_train)
y_preds = model.predict(X_test)


# METRICS
r2 = r2_score(y_test, y_preds)
mae = mean_absolute_error(y_test, y_preds)
rmse = np.sqrt(mae)

print(f"Metrics of r2: {r2*100:.2f}%, mae:{mae:.4f}, rmse:{rmse:.4f}")
# Out:
# Metrics of r2: 55.59%, mae:0.2820, rmse:0.5310

# %% [markdown]
# # Model with no select features (polynominal regression)

# %%
X = df.drop(columns=['fetal_health'])
y = df['fetal_health']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size= 0.25, random_state= 42)

for x in range(2, 3):

    model = Pipeline([
    ("Scaler", StandardScaler()),
    ('poly', PolynomialFeatures(degree=x)),
    ('linear', LinearRegression())
])
    model.fit(X_train, y_train)
    y_preds = model.predict(X_test)
    # METRICS
    r2 = r2_score(y_test, y_preds)
    mae = mean_absolute_error(y_test, y_preds)
    rmse = np.sqrt(mae)

    print(f"Metrics of  deegre: {x}, r2: {r2*100:.2f}%, mae:{mae:.4f}, rmse:{rmse:.4f}")
# Out:
# Metrics of  deegre: 2, r2: 68.25%, mae:0.2278, rmse:0.4773

# %% [markdown]
# # Model with no select features (SGD regression)

# %%
X = df.drop(columns=['fetal_health'])
y = df['fetal_health']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size= 0.25, random_state= 42)
model = Pipeline([
    ("Scaler", StandardScaler()),
    ('SGD', SGDRegressor(
        loss='huber',
        eta0= 0.042,
        learning_rate='adaptive',
        random_state= 92,
        max_iter= 100
    ))
])
model.fit(X_train, y_train)
y_preds = model.predict(X_test)


# METRICS
r2 = r2_score(y_test, y_preds)
mae = mean_absolute_error(y_test, y_preds)
rmse = np.sqrt(mae)

print(f"Metrics of r2: {r2*100:.2f}%, mae:{mae:.4f}, rmse:{rmse:.4f}")
# Out:
# Metrics of r2: 55.82%, mae:0.2279, rmse:0.4774

# %% [markdown]
# Model with no select features (Decision Tree)

# %%
X = df.drop(columns=['fetal_health'])
y = df['fetal_health']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size= 0.25, random_state= 42)
model = Pipeline([
    ("Scaler", StandardScaler()),
    ('SGD', DecisionTreeRegressor(max_depth=10))
])
model.fit(X_train, y_train)
y_preds = model.predict(X_test)


# METRICS
r2 = r2_score(y_test, y_preds)
mae = mean_absolute_error(y_test, y_preds)
rmse = np.sqrt(mae)

print(f"Metrics of r2: {r2*100:.2f}%, mae:{mae:.4f}, rmse:{rmse:.4f}")
# Out:
# Metrics of r2: 74.92%, mae:0.0793, rmse:0.2815

# %% [markdown]
# # Implementing Random Forest model

# %%
from sklearn.ensemble import RandomForestRegressor


forest = RandomForestRegressor(n_estimators=200, random_state=42, max_depth=13, min_samples_split=10, ccp_alpha= 0.0001)
forest.fit(X_train, y_train)


y_preds = forest.predict(X_train)
r2 = r2_score(y_train, y_preds)
mae = mean_absolute_error(y_train, y_preds)
rmse = np.sqrt(mae)
print(f"Metrics, r2: {r2*100:.2f}%, mae:{mae:.4f}, rmse:{rmse:.4f}")


# CHECK ACCURACY OF TEST
y_preds = forest.predict(X_test)
r2 = r2_score(y_test, y_preds)
mae = mean_absolute_error(y_test, y_preds)
rmse = np.sqrt(mae)
print(f"Metrics, r2: {r2*100:.2f}%, mae:{mae:.4f}, rmse:{rmse:.4f}")
# Out:
# Metrics, r2: 94.05%, mae:0.0630, rmse:0.2510
# Metrics, r2: 85.49%, mae:0.0925, rmse:0.3041
