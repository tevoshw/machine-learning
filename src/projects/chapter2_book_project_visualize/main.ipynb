# %% [markdown]
# # FOR THIS PROJECT I WILL USE THE INSTRUCTIONS PRESENTS ON HAND-ON-IN MACHINE LEARNING WITH SCIKIT LEARN.... BY AURÉLION GERON

# %% [markdown]
# ### 1. Analisando o panorama geral e abordando o problema
#
# Nesse caso utilizaremos os dados de um conjunto de preços de imóveis da California, na qual devemos prever os preços, para outro modelo prever se vale a pena o investimento ou não.
#
# E utilizaremos um modelo supervisionado, de regressão, em batch (offline) e por modelo, querendo prever números, com a medida de desempenho escolhida sendo a RMSE (raiz do errro quadrático médio)

# %% [markdown]
# ### 2. Obter os dados
#
# Utilizaremos como no livro se fala os dados presentes em https://github.com/ageron/handson-ml2/tree/master/datasets/housing
#
# Porem nesse caso eu irei abaixar o .csv e colocar em src/datasets

# %%
import pandas as pd 
dataset = pd.read_csv("../../datasets/housing.csv")
dataset.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY
