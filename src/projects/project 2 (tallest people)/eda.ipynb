# %% [markdown]
# # THIS IS THE EDA PART OF PROJECT 2 -> TALLEST PERSON IN THE WORLD

# %%
# IMPORT THE DATASET AND VERIFY THE SIMPLES THINGS

import pandas as pd


dataset = pd.read_csv('../../datasets/tallest_people_in_the_world.csv')
